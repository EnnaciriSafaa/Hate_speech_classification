# %% [markdown]
# # Toxic Comments Classification - LR

# %% [markdown]
# #### Author: SAFAA ENNACIRI - ENNS11538307
# #### Research Director: M. HAKIM LOUNIS

# %% [markdown]
# Dataset: JgsawToxic dataset is a dataset of comments from Wikipedia’s talk page edits. It is avaialble at Kaggle (https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/data).
#
#
# The comments are divided in two classes: toxic and normal.
#
# Algorithme used: LR
#
# Preprocessing techniques used:
# * Lowercase
# * Remove stop words
# * Remove special caracters and numbers
# * Tokenization (accept all kind of tokens except spaces (carriage returns, line breaks, tabs and multiple spaces))

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import metrics
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, cross_val_predict
from matplotlib import pyplot as plt 
import seaborn as sns
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
import pickle
import openpyxl 
from openpyxl import Workbook
from openpyxl.styles import Alignment
from openpyxl.styles.borders import Border, Side

# %% [markdown]
# # 2. Data Preparation

# %%
# Load training data
df = pd.read_csv('../../Data/train_set4.csv')
df.head()
# Out:
#       id                                               text  tox  \
# 0  30351  2few recognize that refugee crisis & associate...    0
# 1  31565  @RandomRandomero @shoe0nhead Also shut up abou...    1
# 2    764  WATCH: Democratic Senator Doesn't Understand T...    1
# 3   2106  IS-puppets tried to roll me over three times! ...    1
# 4   5979  WHO.. ARE. YOOUU? This is not mario kart. You ...    1
#
#                                            tokenized
# 0  ['2few', 'recognize', 'that', 'refugee', 'cris...
# 1  ['@', 'RandomRandomero', '@', 'shoe0nhead', 'A...
# 2  ['WATCH', ':', 'Democratic', 'Senator', 'Does'...
# 3  ['IS-puppets', 'tried', 'to', 'roll', 'me', 'o...
# 4  ['WHO', '..', 'ARE', '.', 'YOOUU', '?', 'This'...

# %%
# Load testing data
test = pd.read_csv('../../Data/test_set4.csv')
test.head()
# Out:
#       id                                               text  tox  \
# 0   3816  #BuildThatWall #Meritbased get the ILLEGAL sit...    1
# 1   2737  Angels Don't Die. I think it's better that two...    0
# 2   5598  When your girls actin a fool so you let your s...    1
# 3  19183                             @PYS_FlyATL You pussy.    0
# 4   1699  Tomorrow night our guest speaker is Madeleine ...    0
#
#                                            tokenized
# 0  ['#', 'BuildThatWall', '#', 'Meritbased', 'get...
# 1  ['Angels', 'Do', "n't", 'Die', '.', 'I', 'thin...
# 2  ['When', 'your', 'girls', 'actin', 'a', 'fool'...
# 3           ['@', 'PYS_FlyATL', 'You', 'pussy', '.']
# 4  ['Tomorrow', 'night', 'our', 'guest', 'speaker...

# %% [markdown]
# # 3. Preprocessing

# %%
stop_words = set(stopwords.words('english'))

# %%
print(stop_words)
# Out:
# {'between', 'there', "should've", 'mustn', 'd', 'nor', "you'll", 'down', 'why', 'being', 'all', "won't", 'me', 'what', 'ours', 'can', 'needn', "doesn't", "don't", 'itself', 'during', 'for', 'haven', 'o', 'them', 'yourself', 'been', 'under', 'against', "you've", 'weren', 'our', "mustn't", 'just', 'shouldn', 'out', 'the', 're', 've', 'yourselves', 'which', 'wasn', 'hers', 'hadn', 'has', 'ain', 'we', 'hasn', 'herself', 'too', 'in', 'over', 'about', 'she', "that'll", 'off', 'did', 'no', 'on', 'where', "she's", 'below', 'now', 'a', 't', "it's", 'as', 'ourselves', 'of', 'him', "shan't", 'not', 'own', 'both', 'shan', 's', 'mightn', 'here', "didn't", 'at', 'because', 'i', 'so', 'won', 'through', "needn't", 'but', "shouldn't", 'until', 'don', 'an', 'than', "wouldn't", 'each', "aren't", 'himself', 'it', 'aren', 'doesn', 'that', 'her', 'or', 'had', 'by', 'few', 'll', 'he', 'couldn', 'once', 'they', 'with', 'whom', 'be', 'more', "couldn't", 'will', 'only', 'such', 'into', "wasn't", 'themselves', 'other', 'didn', 'if', 'having', "weren't", 'and', 'myself', 'am', 'while', 'theirs', 'does', 'were', 'doing', 'are', 'this', 'wouldn', 'his', 'who', 'up', 'your', 'how', "haven't", 'you', 'was', 'm', 'some', 'very', "you're", 'same', 'above', 'to', 'any', 'should', "mightn't", 'its', 'y', 'further', 'isn', "isn't", "hadn't", 'is', 'before', "hasn't", 'these', 'when', 'yours', 'again', 'ma', 'do', 'after', 'from', "you'd", 'my', 'their', 'have', 'those', 'most', 'then'}

# %%
def clean_text(comment): 

    comment = comment.lower() # Normalize to lowercase         
    word_tokens = comment.split(' ') #word_tokenize(comment)
    
    filtered_comment = []  
    # converts the words in word_tokens tand tchecks whether 
    #they are present in stop_words or not
    for w in word_tokens:
        if w not in stop_words:
            filtered_comment.append(w)

    comment = (" ").join(filtered_comment)
    
    comment = re.sub(r'[^a-zA-Z]', ' ',comment) # remove special caracters and nuumbers 
    comment = re.sub(r'[“”¨«»®´·º½¾¿¡§£₤‘’]', ' ', comment) # Remove special characters
    
    return comment

# %%
# clean and normalize comments
df['text'] = df['text'].map(lambda word:clean_text(word))
test['text'] = test['text'].map(lambda word:clean_text(word))

# %%
x_train = df['text']
y_train = df['tox']

#Check shape of data
print(x_train.shape)
print(y_train.shape)
# Out:
# (10400,)
# (10400,)

# %%
X_test = test['text']
Y_test = test['tox']

#Check shape of data
print(X_test.shape)
print(Y_test.shape)
# Out:
# (2600,)
# (2600,)

# %% [markdown]
# # 3. Classifier training (LR)

# %% [markdown]
# ### Create pipeline

# %%
# create a pipeline
model_pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(lowercase=False, 
                                          token_pattern=r'\S+', max_features=20000)),
                ('clf', LogisticRegression(max_iter=1000, random_state=0, verbose=True, C=1,
                                           class_weight=None, penalty='l1', solver='liblinear'))])

# %% [markdown]
# ### Train classifier

# %%
# cross validation
metrics = ['accuracy', 'recall', 'f1', 'precision']
result = cross_validate (model_pipeline, x_train, y_train, cv=5, scoring = metrics,  return_estimator=True)
# Out:
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]

# %%
# save models
model_fit = result['estimator']
i = 0
for model in model_fit:
    dir_name = "models/Set1_approach#26_" + str(i) + ".sav"
    pickle.dump(model, open(dir_name, 'wb'))
    i = i + 1

# %% [markdown]
# ### Evaluate metrics

# %%
# Model Evaluation metrics for train data
train_accuracy = "%.4f" % (result['test_accuracy'].mean())
train_recall  = "%.4f" % (result['test_recall'].mean())
train_F1_score  = "%.4f" % (result['test_f1'].mean())
train_precision  = "%.4f" % (result['test_precision'].mean())

# Print scores for evaluation metrics
print('Results for train data')
print ('-----------------------')
print('Accuracy score : ', train_accuracy)
print('recall : ', train_recall)
print('F1_score : ' , train_F1_score)
print('precision : ' , train_precision)
# Out:
# Results for train data
# -----------------------
# Accuracy score :  0.7397
# recall :  0.6378
# F1_score :  0.6713
# precision :  0.7086

# %% [markdown]
# # 4. Predictions

# %% [markdown]
# ### Test set

# %%
# predict test data
preds_test = cross_val_predict(model_pipeline, X_test, Y_test, cv=5)
# Out:
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]

# %%
# svm Confusion matrix
print('\n confusion matrix for test data \n')
print((confusion_matrix(Y_test, preds_test)))
# Out:
#  confusion matrix for test data
#
# [[1163  302]
#  [ 471  664]]

# %%
# svm classification report
print('\n\n classification report for test data \n')
print(classification_report(Y_test, preds_test, target_names=['normal','toxic']))
# Out:
#  classification report for test data
#
#               precision    recall  f1-score   support
#
#       normal       0.71      0.79      0.75      1465
#        toxic       0.69      0.59      0.63      1135
#
#     accuracy                           0.70      2600
#    macro avg       0.70      0.69      0.69      2600
# weighted avg       0.70      0.70      0.70      2600

# %%
# plot confusion matrix
conf_mat = confusion_matrix(Y_test, preds_test)
fig, ax = plt.subplots(figsize=(10,10))
cmap = "tab20"
sns.heatmap(conf_mat, annot=True, fmt='d',cmap=cmap)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# Model Evaluation metrics for test data
test_accuracy = "%.4f" % (accuracy_score(Y_test, preds_test))
test_recall  = "%.4f" % (recall_score(Y_test, preds_test))
test_F1_score  = "%.4f" % (f1_score(Y_test, preds_test))
test_precision  = "%.4f" % (precision_score(Y_test, preds_test))

# Print scores for evaluation metrics
print('Results for test data')
print ('-----------------------')
print('Accuracy score : ', test_accuracy)
print('recall : ', test_recall)
print('F1_score : ' , test_F1_score)
print('precision : ' , test_precision)
# Out:
# Results for test data
# -----------------------
# Accuracy score :  0.7027
# recall :  0.5850
# F1_score :  0.6321
# precision :  0.6874

# %% [markdown]
# # 5. Save results to Excel file

# %%
# define tarjet
newFile = "../results_LR_set4.xlsx"

# open excel file
workbook = openpyxl.load_workbook(filename = newFile)        
worksheet = workbook.active
    
# scores for evaluation metrics
data = {1:'Approach #3', 2:train_accuracy, 3:train_recall, 4:train_F1_score, 5:train_precision, 
                  6:test_accuracy, 7:test_recall, 8:test_F1_score, 9:test_precision}

# row's index for approach
index = 5

# delete row of approach
worksheet.delete_rows(index, 1)

# insert data in excel sheet
worksheet.insert_rows(index)
for col, value in data.items():
    worksheet.cell(row=index, column=col, value=value)
    
# define style border
thin_border = Border(left=Side(style='thin'), 
                     right=Side(style='thin'), 
                     top=Side(style='thin'), 
                     bottom=Side(style='thin'))
cell_alignment = Alignment(horizontal='center')

# apply style border
for row in worksheet:
    for cell in row:
        cell.border = thin_border
        cell.alignment = cell_alignment
    
# save file
workbook.save(newFile)
