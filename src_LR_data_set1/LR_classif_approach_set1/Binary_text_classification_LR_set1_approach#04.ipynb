# %% [markdown]
# # Toxic Comments Classification - LR

# %% [markdown]
# #### Author: SAFAA ENNACIRI - ENNS11538307
# #### Research Director: M. HAKIM LOUNIS

# %% [markdown]
# Dataset: JgsawToxic dataset is a dataset of comments from Wikipedia’s talk page edits. It is avaialble at Kaggle (https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/data).
#
#
# The comments are divided in two classes: toxic and normal.
#
# Algorithme used: LR
#
# Preprocessing techniques used:
# * Convert text to lowercase
# * Remove special caracters and numbers
# * Remove stop words
# * Tokenization (accept all kind of tokens except spaces (carriage returns, line breaks, tabs and multiple spaces))

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import metrics
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, cross_val_predict
from matplotlib import pyplot as plt 
import seaborn as sns
import pickle
import openpyxl 
from openpyxl import Workbook
from openpyxl.styles import Alignment
from openpyxl.styles.borders import Border, Side
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re

# %% [markdown]
# # 2. Data Preparation

# %%
# Load training data
df = pd.read_csv('../../Data/train_set1.csv')
df.head()
# Out:
#                  id                                       comment_text  tox
# 0  20ca7bad20d4c3d1  You're an asshole, useless piece of shit. Get ...    1
# 1  72428510d4205ccf  Nonito Donaire \n\nIt is clearly stated in the...    0
# 2  f3890d4a31f0d45a  Okay, in the future I shall no longer use the ...    0
# 3  29ac5b2897f7ef59         fuck off \n\ndon't fuck with me . fuck off    1
# 4  6f2278059a63256a  "*E-dog, on another page, you wrote: \n\nThank...    1

# %%
# Load testing data
test = pd.read_csv('../../Data/test_set1.csv')
test.head()
# Out:
#                  id                                       comment_text  tox
# 0  b28eeb594e5ac00f  AAAAWWWW, widdle wikinazis banned me.\n\nMaybe...    1
# 1  2f3c460abcd5479f  very crocker sucks n e g r o c o c k s i n h e...    1
# 2  dc3ae57fa0c30d8d               He lied on my RFC too.  He's a liar.    1
# 3  5eb7bb36f870d2b9  "I've removed the following:\n""Morro Bay is a...    0
# 4  e9c9d9abd37bca1d  Briefcase\n\nToo much importance is given to t...    0

# %% [markdown]
# # 3. Preprocessing

# %%
stop_words = set(stopwords.words('english'))

# %%
print(stop_words)
# Out:
# {'don', 'its', 'doesn', 'me', 'your', 'both', 'been', 'has', 'can', 'doing', 'after', 'will', 'for', 'any', 'then', 'these', 'we', 'this', "you're", 'very', 'of', 'my', 'same', 'she', "should've", 'hasn', "it's", 'should', 'as', "you've", 've', 'under', 'them', "doesn't", 'above', 'until', 'were', 'y', 'theirs', 'further', "that'll", 'but', 'haven', 'ourselves', "hadn't", 'no', 'now', 'their', 'i', 'wouldn', 'not', "needn't", 'what', 'there', 'some', 'in', 'each', 'all', 'couldn', 'too', "didn't", "mustn't", 'needn', 'most', 'here', 'it', 'to', 'own', 'ain', 'are', 'd', 'nor', 'such', 'by', 'he', 'be', 't', 'won', 'off', 'few', 'more', 'those', "won't", 'up', "wouldn't", 'ours', 'about', 'why', 'down', "she's", 'where', 'between', 'mightn', 'that', 'him', 'while', 'into', 'shan', "weren't", 'once', 'out', "wasn't", 'than', "isn't", 'at', 'is', 'other', 'during', 'aren', 'and', "you'd", 'myself', 'who', "aren't", 'mustn', 'am', "couldn't", 'herself', 'whom', 'itself', 'below', 'hers', 'the', 'when', 'o', "you'll", 'with', 'again', 'his', 'themselves', 'does', 'yours', "shan't", 'did', 'was', 'which', 'll', 'over', 'if', 'himself', 'her', 'on', 'because', 's', 'or', 'yourselves', 'had', 'have', "don't", "hasn't", 'you', 'from', 'having', 'shouldn', 'our', 'just', 'hadn', 'didn', 'they', 'm', 'how', 'weren', 'only', 'being', "haven't", 'do', 'so', 'against', 'before', 're', 'isn', 'through', "mightn't", 'an', 'ma', 'yourself', 'a', 'wasn', "shouldn't"}

# %%
def clean_text(comment): 

    comment = comment.lower() # Normalize to lowercase 
    comment = re.sub(r'[^a-zA-Z]', ' ',comment) # remove special caracters and nuumbers 
    comment = re.sub(r'[“”¨«»®´·º½¾¿¡§£₤‘’]', ' ', comment) # Remove special characters
    word_tokens = comment.split(' ') #word_tokenize(comment)
    
    filtered_comment = []  
    # converts the words in word_tokens tand tchecks whether 
    #they are present in stop_words or not
    for w in word_tokens:
        if w not in stop_words:
            filtered_comment.append(w)

    comment = (" ").join(filtered_comment)
    
    return comment

# %%
# clean and normalize comments
df['comment_text'] = df['comment_text'].map(lambda word:clean_text(word))
test['comment_text'] = test['comment_text'].map(lambda word:clean_text(word))

# %%
x_train = df['comment_text']
y_train = df['tox']

#Check shape of data
print(x_train.shape)
print(y_train.shape)
# Out:
# (25960,)
# (25960,)

# %%
X_test = test['comment_text']
Y_test = test['tox']

#Check shape of data
print(X_test.shape)
print(Y_test.shape)
# Out:
# (6490,)
# (6490,)

# %% [markdown]
# # 3. Classifier training (LR)

# %% [markdown]
# ### Create pipeline

# %%
# create a pipeline
model_pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(lowercase=False, 
                                          token_pattern=r'\S{3,}', max_features=20000)),
                ('clf', LogisticRegression(max_iter=1000, random_state=0, verbose=True, C=10,
                                           class_weight='balanced', penalty='l1', solver='saga'))])

# %% [markdown]
# ### Train classifier

# %%
# cross validation
metrics = ['accuracy', 'recall', 'f1', 'precision']
result = cross_validate (model_pipeline, x_train, y_train, cv=5, scoring = metrics,  return_estimator=True)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# max_iter reached after 392 seconds
# /home/laboratoire/.pyenv/versions/3.7.8/envs/labo/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.5min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 798 epochs took 327 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.5min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 642 epochs took 260 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.3min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 733 epochs took 284 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.7min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 763 epochs took 307 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.1min finished

# %%
# save models
svc_fit = result['estimator']
i = 0
for model in svc_fit:
    dir_name = "models/Set1_approach#4_" + str(i) + ".sav"
    pickle.dump(model, open(dir_name, 'wb'))
    i = i + 1

# %% [markdown]
# ### Evaluate metrics

# %%
# Model Evaluation metrics for train data
train_accuracy = "%.4f" % (result['test_accuracy'].mean())
train_recall  = "%.4f" % (result['test_recall'].mean())
train_F1_score  = "%.4f" % (result['test_f1'].mean())
train_precision  = "%.4f" % (result['test_precision'].mean())

# Print scores for evaluation metrics
print('Results for train data')
print ('-----------------------')
print('Accuracy score : ', train_accuracy)
print('recall : ', train_recall)
print('F1_score : ' , train_F1_score)
print('precision : ' , train_precision)
# Out:
# Results for train data
# -----------------------
# Accuracy score :  0.8944
# recall :  0.8718
# F1_score :  0.8918
# precision :  0.9127

# %% [markdown]
# # 4. Predictions

# %% [markdown]
# ### Test set

# %%
# predict test data
preds_test = cross_val_predict(model_pipeline, X_test, Y_test, cv=5)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 730 epochs took 33 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   33.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 681 epochs took 32 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   31.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 734 epochs took 27 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   26.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 794 epochs took 16 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 715 epochs took 16 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.9s finished

# %%
# svm Confusion matrix
print('\n confusion matrix for test data \n')
print((confusion_matrix(Y_test, preds_test)))
# Out:
#  confusion matrix for test data
#
# [[2931  290]
#  [ 564 2705]]

# %%
# svm classification report
print('\n\n classification report for test data \n')
print(classification_report(Y_test, preds_test, target_names=['normal','toxic']))
# Out:
#  classification report for test data
#
#               precision    recall  f1-score   support
#
#       normal       0.84      0.91      0.87      3221
#        toxic       0.90      0.83      0.86      3269
#
#     accuracy                           0.87      6490
#    macro avg       0.87      0.87      0.87      6490
# weighted avg       0.87      0.87      0.87      6490

# %%
# plot confusion matrix
conf_mat = confusion_matrix(Y_test, preds_test)
fig, ax = plt.subplots(figsize=(10,10))
cmap = "tab20"
sns.heatmap(conf_mat, annot=True, fmt='d',cmap=cmap)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# Model Evaluation metrics for test data
test_accuracy = "%.4f" % (accuracy_score(Y_test, preds_test))
test_recall  = "%.4f" % (recall_score(Y_test, preds_test))
test_F1_score  = "%.4f" % (f1_score(Y_test, preds_test))
test_precision  = "%.4f" % (precision_score(Y_test, preds_test))

# Print scores for evaluation metrics
print('Results for test data')
print ('-----------------------')
print('Accuracy score : ', test_accuracy)
print('recall : ', test_recall)
print('F1_score : ' , test_F1_score)
print('precision : ' , test_precision)
# Out:
# Results for test data
# -----------------------
# Accuracy score :  0.8684
# recall :  0.8275
# F1_score :  0.8637
# precision :  0.9032

# %% [markdown]
# # 5. Save results to Excel file

# %%
# define tarjet
newFile = "../results_LR_set1.xlsx"

# open excel file
workbook = openpyxl.load_workbook(filename = newFile)        
worksheet = workbook.active
    
# scores for evaluation metrics
data = {1:'Approach #4', 2:train_accuracy, 3:train_recall, 4:train_F1_score, 5:train_precision, 
                  6:test_accuracy, 7:test_recall, 8:test_F1_score, 9:test_precision}

# row's index for approach
index = 6

# delete row of approach
worksheet.delete_rows(index, 1)

# insert data in excel sheet
worksheet.insert_rows(index)
for col, value in data.items():
    worksheet.cell(row=index, column=col, value=value)
    
# define style border
thin_border = Border(left=Side(style='thin'), 
                     right=Side(style='thin'), 
                     top=Side(style='thin'), 
                     bottom=Side(style='thin'))
cell_alignment = Alignment(horizontal='center')

# apply style border
for row in worksheet:
    for cell in row:
        cell.border = thin_border
        cell.alignment = cell_alignment
    
# save file
workbook.save(newFile)
