# %%
import pandas as pd
import numpy as np
import pickle
import time

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# list of text documents
text = ['@covidcreations fucking @clif_high #coronaviru2s  ']
# create the transform
vectorizer = TfidfVectorizer(lowercase=False,token_pattern=r'\S+')#, analyzer='char_wb', ngram_range=(3,8))
# tokenize and build vocab
#vectorizer.fit(text)
# summarize
#print(vectorizer.vocabulary_)
#print('*******')
#tokenizer = lambda docs: [vectorizer.build_tokenizer()(doc) for doc in docs]

#print(tokenizer(text))

vectorizer .fit(text)
#vectorizer .vocabulary_
vectorizer.get_feature_names_out()
# Out:
# array(['#coronaviru2s', '@clif_high', '@covidcreations', 'fucking'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(token_pattern=r'\S+')

text = ["This is 000 Sparta!"]
tfidf_matrix =  tf.fit(text)
feature_names = tf.get_feature_names() 

print(feature_names)
# Out:
# ['000', 'is', 'sparta!', 'this']

# %%
def return_text(text):
    return text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# list of text documents
text = ['@CoviDcreations @clif_high #coronavirus Report has been published first time and results are extremely serious.   Coronavirus has become the biggest challenge of 2020 in front of Scientists and health experts.  Like, RT: https://t.co/lKia09KKE9 #CoronavirusOutbreak #wuhan #chinavirus #coronaviruschina']
# create the transform
vectorizer = TfidfVectorizer(lowercase=False, tokenizer=return_text, preprocessor=return_text,token_pattern='\S+')
# tokenize and build vocab
#vectorizer.fit(text)
# summarize
#print(vectorizer.vocabulary_)
#print('*******')
#tokenizer = lambda docs: [vectorizer.build_tokenizer()(doc) for doc in docs]

#print(tokenizer(text))

vectorizer .fit(text)
#vectorizer .vocabulary_
vectorizer.get_feature_names_out()
# Out:
# /home/laboratoire/.pyenv/versions/3.7.8/envs/labo/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# array([' ', '#', ',', '.', '/', '0', '2', '9', ':', '@', 'C', 'D', 'E',
#        'K', 'L', 'O', 'R', 'S', 'T', '_', 'a', 'b', 'c', 'd', 'e', 'f',
#        'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u',
#        'v', 'w', 'x', 'y'], dtype=object)

# %%
docs = [
    ['Two', 'wrongs', 'don\'t', 'make', 'a', 'right', '.'],
    ['The', 'pen', 'is', 'mightier', 'than', 'the', 'sword'],
    ['Don\'t', 'put', 'all', 'your', 'eggs', 'in', 'one', 'basket', '.']
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def dummy_fun(doc):
    return doc
vectorizer  = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None)

# %%
print (dummy_fun(docs))
# Out:
# [['Iterable', 'over', 'raw', 'text', 'documents', 'expected,', 'string', 'object', 'received']]

# %%
vectorizer .fit(docs)
#vectorizer .vocabulary_
vectorizer.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-cb3c909d6f2a> in <module>
# ----> 1 vectorizer .fit(dummy_fun(docs))
#       2 #vectorizer .vocabulary_
#       3 vectorizer.get_feature_names_out()
#
# ~/.pyenv/versions/3.7.8/envs/labo/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#    2051         self._check_params()
#    2052         self._warn_for_unused_params()
# -> 2053         X = super().fit_transform(raw_documents)
#    2054         self._tfidf.fit(X)
#    2055         return self
#
# ~/.pyenv/versions/3.7.8/envs/labo/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1328                     break
#    1329
# -> 1330         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1331
#    1332         if self.binary:
#
# ...

# %%
text2 = '@CoviDcreations @clif_high #coronavirus Report has been published first time and results are extremely serious.   Coronavirus has become the biggest challenge of 2020 in front of Scientists and health experts.  Like, RT: https://t.co/lKia09KKE9 #CoronavirusOutbreak #wuhan #chinavirus #coronaviruschina'
text = 'The second member of his surname is not spelled right... It starts with an F \n You know, Carter-F*ck'
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
stop_words = set(stopwords.words('english'))
def clean_text(text1): 

    text1 = text1.lower() # Normalize to lowercase 
    
    text1 = re.sub(r'[^a-zA-Z]', ' ',text1) # Remove all punctuations, special characters and numbers
    text1 = re.sub(r'[“”¨«»®´·º½¾¿¡§£₤‘’]', ' ', text1) # Remove special characters
    text1 = re.sub('[\\r\\t]', ' ', text1)
    text1 = re.sub(' +', ' ', text1)
            
    word_tokens = text1.split(' ') #word_tokenize(text)
    
    filtered_comment = []  
    # converts the words in word_tokens tand tchecks whether 
    #they are present in stop_words or not
    for w in word_tokens:
        if w.lower() not in stop_words:
            filtered_comment.append(w)

    comment = (" ").join(filtered_comment)
    
    #comment=text1
    return comment

# %%
text_stop = clean_text(text2)
print(text_stop)
# Out:
#  covidcreations clif high coronavirus report published first time results extremely serious coronavirus become biggest challenge front scientists health experts like rt https co lkia kke coronavirusoutbreak wuhan chinavirus coronaviruschina

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import metrics
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, cross_val_predict
from matplotlib import pyplot as plt 
import seaborn as sns
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
import pickle
import openpyxl 
from openpyxl import Workbook
from openpyxl.styles import Alignment
from openpyxl.styles.borders import Border, Side

# %%
def clean_text(comment): 

    comment = comment.lower() # Normalize to lowercase 
    #comment = re.sub("@\S+", " ", comment) # Remove usernames
    #comment = re.sub("https*\S+", " ", comment) # Remove URL
    #comment = comment.replace("#", "") #remove hashtag
    #comment = re.sub("\\<([^/> ]+)", " ", comment) # Remove HTML tags
    #comment = re.sub(r'[^a-zA-Z]', ' ',comment) # remove special caracters and nuumbers 
    #comment = re.sub(r'[“”¨«»®´·º½¾¿¡§£₤‘’]', ' ', comment) # Remove special characters
    
    return comment

# %%
def print_text(sample, clean):
    print(f"Before: {sample}")
    print(f"After: {clean}")

# %%
from collections import Counter
sample_text = "Youre such an ugly fucking bitch and I take back no words I said to you and I wish I slapped you when you were stood infront of me blahing your eyes out you pussy bitch"
sample_t=clean_text(sample_text)

# %%
u='youre ugly fucking bitch take back words said wish slapped stood infront blahing eyes pussy bitch'

# %%
from collections import Counter

#def remove_rare_words(text, threshold=5):
words = sample_t.split(' ')#nltk.word_tokenize(sample_t)
print(words)
word_freq = Counter(words)
print(word_freq)
e = word_freq.most_common(10)
print(e)
g=[e[0][0],e[1][0],e[2][0],e[3][0], e[4][0]]
#print(g)
#f = word_freq.most_common()[-10:]
#print(f)
#g=[e[0][0],e[1][0],e[2][0],e[3][0], e[4][0], e[5][0], e[6][0], e[7][0], e[8][0], e[9][0]]
print(g)


filtered_words = [word for word in words if word not in g]

text= ' '.join(filtered_words)

#text = remove_rare_words(text, threshold=2)
text  
print(text)
# Out:
# ['youre', 'such', 'an', 'ugly', 'fucking', 'bitch', 'and', 'i', 'take', 'back', 'no', 'words', 'i', 'said', 'to', 'you', 'and', 'i', 'wish', 'i', 'slapped', 'you', 'when', 'you', 'were', 'stood', 'infront', 'of', 'me', 'blahing', 'your', 'eyes', 'out', 'you', 'pussy', 'bitch']
# Counter({'i': 4, 'you': 4, 'bitch': 2, 'and': 2, 'youre': 1, 'such': 1, 'an': 1, 'ugly': 1, 'fucking': 1, 'take': 1, 'back': 1, 'no': 1, 'words': 1, 'said': 1, 'to': 1, 'wish': 1, 'slapped': 1, 'when': 1, 'were': 1, 'stood': 1, 'infront': 1, 'of': 1, 'me': 1, 'blahing': 1, 'your': 1, 'eyes': 1, 'out': 1, 'pussy': 1})
# [('i', 4), ('you', 4), ('bitch', 2), ('and', 2), ('youre', 1), ('such', 1), ('an', 1), ('ugly', 1), ('fucking', 1), ('take', 1)]
# ['i', 'you', 'bitch', 'and', 'youre']
# such an ugly fucking take back no words said to wish slapped when were stood infront of me blahing your eyes out pussy

# %%
from collections import Counter

#def remove_rare_words(text, threshold=5):
words = u.split(' ')
word_freq = Counter(words)
#print(word_freq)
#e = word_freq.most_common(10)
#print(e)

f = word_freq.most_common()[-10:]
print(f)
g=[e[0][0],e[1][0],e[2][0],e[3][0], e[4][0]]
print(g)


filtered_words = [word for word in words if word not in g]

text= ' '.join(filtered_words)

#text = remove_rare_words(text, threshold=2)
text  
print(text)
# Out:
# [('back', 1), ('words', 1), ('said', 1), ('wish', 1), ('slapped', 1), ('stood', 1), ('infront', 1), ('blahing', 1), ('eyes', 1), ('pussy', 1)]
# ['i', 'you', 'bitch', 'and', 'youre']
# ugly fucking take back words said wish slapped stood infront blahing eyes pussy

# %%
stop_words = set(stopwords.words('english'))
r='Youre such an ugly fucking bitch and I take back no words I said to you and I wish I slapped you when you were stood infront of me blahing your eyes out you pussy bitch'

# %%
word_tokens = sample_t.split(' ') #word_tokenize(comment)
    
filtered_comment = []  
# converts the words in word_tokens tand tchecks whether 
#they are present in stop_words or not
for w in word_tokens:
    if w not in stop_words:
        filtered_comment.append(w)

comment = (" ").join(filtered_comment)
print(comment)
# Out:
# youre ugly fucking bitch take back words said wish slapped stood infront blahing eyes pussy bitch

# %%
tokens = sample_text.split()
clean_tokens = [t for t in tokens if len(t) > 2]
clean_text = " ".join(clean_tokens)
print_text(sample_text, clean_text)
# Out:
# Before: this is a sample text. I'll remove the a
# After: this sample text. I'll remove the
