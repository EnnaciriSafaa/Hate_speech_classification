# %% [markdown]
# # Toxic Comments Classification - SVM

# %% [markdown]
# #### Author: SAFAA ENNACIRI - ENNS11538307
# #### Research Director: M. HAKIM LOUNIS

# %% [markdown]
# Dataset: Toxic Comment Classification dataset is a dataset of comments from Wikipedia’s talk page edits.  It is avaialble at http://claws.cc.gatech.edu/covid/#dataset.
#
#
# The comments are devided in two categories: toxic and normal.
#
# Algorithme used: SVM
#
# Technique used: GreadSearchCV

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import pickle, time

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, precision_recall_fscore_support, accuracy_score
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # 2. Data Preparation

# %% [markdown]
# ## 2.1 Load and explore data

# %%
# Load training data
df = pd.read_csv('../../Data/train_set3.csv')
df.head()
# Out:
#               Tweet ID                                               Text  tox
# 0  1232251751035756548  I want some chinamen hella bad I wish this cor...    0
# 1  1237917204659589120  @WhiteHouse House Dems want to pass a bill pre...    0
# 2  1245350969594036225  n ppl tried to come at me saying “stop calling...    1
# 3  1245078318367387648  @AliciaRedd2 @itsJeffTiedrich @realDonaldTrump...    1
# 4  1230567454234906624  @CoviDcreations @clif_high #coronavirus Report...    0

# %%
X_train = df['Text']
Y_train = df['tox']

#Check shape of data
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1832,)
# (1832,)

# %% [markdown]
# # 3. Classifier training

# %% [markdown]
# ## 3.1 Create pipeline

# %%
start_time=time.time()

SVC_pipeline1 = make_pipeline(TfidfVectorizer(),
                SVC(verbose=True))


param_grid = {'svc__kernel': ['linear','sigmoid','rbf', 'poly'], 
              'svc__gamma': ['auto', 'scale']
             } 

            
grid_3 = GridSearchCV(SVC_pipeline1, param_grid, cv=10, scoring='accuracy', error_score='raise')

grid = grid_3 .fit(X_train, Y_train)

end_time=time.time()
              
print("total time",end_time-start_time)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]total time 44.81903553009033

# %%
print(grid.best_estimator_.named_steps['svc'])
# Out:
# SVC(verbose=True)

# %%
grid.best_params_
# Out:
# {'svc__gamma': 'scale', 'svc__kernel': 'rbf'}

# %%
grid.best_score_
# Out:
# 0.8056664290805416
